# %% [markdown]
# # YouTube & Spotify Top Music Artists From 2018
# ---
#
# ### SCOPE:
# #### - Extracted, transformed, and loaded up YouTube's Top Trending Videos from December 2017 thru May 2018 for their videos categorized as music only, and created an "Artist" column to enable joining with Spotify's Top 100 Songs of 2018. Both dataframes were loaded into MySQL.
#
#
# ### PURPOSE:
# #### - I choose this project because I'm a avid listener and a huge music and concert goer, and wanted to work with data that I was familiar with.
#
# ### Data Sources:
# #### - https://www.kaggle.com/datasnaek/youtube-new (this is an updated link, whereas I used an older version of this file, which is attached in the resources)
# #### - https://www.kaggle.com/nadintamer/top-spotify-tracks-of-2018

# %%
# Import Dependencies 1/2:
import os
import csv
import json
import simplejson
import numpy as np
import pandas as pd
from datetime import datetime
import sys
import string

# %% [markdown]
# ## Part 1) SQL Alchemy setup and built a search, create, and drop database function to set up loading phase after extraction and transformation of data

# %%
# Import Dependencies 2/2:
from sqlalchemy import create_engine, Column, Integer, String, join, Date, Table, MetaData
from sqlalchemy.sql import select
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy_utils import database_exists, create_database, drop_database, has_index
import pymysql

Base = declarative_base()

# %%
#rds_connection_string = "<inser user name>:<insert password>@127.0.0.1/customer_db"
rds_connection_string = "root:gREATNESS23$@127.0.0.1/" #youtube_spotify_2018_db"

# Can set up an input for the db_name later (optional)
#db_name = input("What database would you like to search for?")
db_name = 'youtube_spotify_2018_db2'

# Setup engine connection string
#engine = create_engine(f'mysql://{rds_connection_string}{db_name}?charset=utf8')
engine = create_engine(f'mysql://{rds_connection_string}{db_name}?charset=utf8', echo=True)

# %%
# Created a function incorproating SQL Alchemy to search, create, and or drop a database:
def search_create_drop_db(db_name):
    #db_exist = database_exists(f'mysql://{rds_connection_string}youtube_spotify_2018_db2')
    db_exist = database_exists(f'mysql://{rds_connection_string}{db_name}')
    db_url = f'mysql://{rds_connection_string}{db_name}'
    if db_exist == True:
        drop_table_y_or_n = input(f'"{db_name}" database already exists in MySQL. Do you want you drop the table? Enter exactly: "y" or "n".  ')
        if drop_table_y_or_n == 'y':
            drop_database(db_url)
            print(f"Database {db_name} was dropped")
            create_new_db = input(f"Do you want to create another database called: {db_name}?  ")
            if create_new_db == 'y':
                create_database(db_url)
                return(f"The database {db_name} was created. Next You will need to create tables for this database.  ")
            else:
                return("No database was created. Goodbye!  ")
        else:
            return("The database exists. No action was taken. Goodbye!  ")
    else:
        create_database(db_url)
        return(f"The queried database did not exist, and was created as: {db_name} .  ")

search_create_drop_db(db_name)
# Out:
# "youtube_spotify_2018_db2" database already exists in MySQL. Do you want you drop the table? Enter exactly: "y" or "n".  y
# Database youtube_spotify_2018_db2 was dropped
# Do you want to create another database called: youtube_spotify_2018_db2?  y
# 'The database youtube_spotify_2018_db2 was created. Next You will need to create tables for this database.  '

# %%
# # Create tables 'blueprints' using python classes and sql alchemy:
# # This would be useful say if I was to use SQL Alchemy to import a sqllite file into python

# class yt_categories(Base):
#     __tablename__ = 'yt_category_titles'
#     id = Column(Integer, primary_key=True)
#     category_title = Column(String(60))

# class yt_statistics_data(Base):
#     __tablename__ = 'yt_statistics'
#     id = Column(Integer, primary_key=True)
#     category_title = Column(String(60))
#     trending_date = Column(Date, nullable=False)
#     video_title = Column(String(200))
#     channel_title = Column(String(100))
#     category_id = Column(Integer)
#     views = Column(Integer)
#     likes = Column(Integer)
#     dislikes = Column(Integer)
#     view_count = Column(Integer)

# class spotify_music_data(Base):
#     __tablename__ = 'spotify_music'
#     id = Column(Integer, primary_key=True)
#     artist = Column(String(100))
#     song_name = Column(String(200))
#     spotify_unique_id = Column(String(100))

# %%
# Create tables 'blueprints' using python classes and sql alchemy:

meta = MetaData()
conn = engine.connect()

yt_categories = Table(
   'yt_categories', meta, 
   Column('category_id', Integer, primary_key = True), 
   Column('category_title', String)
)

yt_statistics = Table(
   'yt_statistics', meta, 
   Column('video_id', String, primary_key = True),
   Column('category_title', String),
   Column('trending_date', Date, nullable=False),
   Column('video_title', String),
   Column('channel_title', String),
   Column('category_id', Integer),
   Column('views', Integer),
   Column('likes', Integer),
   Column('dislikes', Integer),
   Column('view_count', Integer)
)

spotify_2018top100_data = Table(
   'spotify_2018top100_data', meta,
   Column('Artist', String, primary_key = True),
   Column('song_name', String),
   Column('unique_id', String)
)
# Out:
# 2020-04-01 23:46:38,018 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2020-04-01 23:46:38,024 INFO sqlalchemy.engine.base.Engine ()
# 2020-04-01 23:46:38,042 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2020-04-01 23:46:38,047 INFO sqlalchemy.engine.base.Engine ()
# 2020-04-01 23:46:38,064 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2020-04-01 23:46:38,071 INFO sqlalchemy.engine.base.Engine ()
# 2020-04-01 23:46:38,075 INFO sqlalchemy.engine.base.Engine show collation where `Charset` = 'utf8mb4' and `Collation` = 'utf8mb4_bin'
# 2020-04-01 23:46:38,077 INFO sqlalchemy.engine.base.Engine ()
# 2020-04-01 23:46:38,083 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2020-04-01 23:46:38,085 INFO sqlalchemy.engine.base.Engine ()
# 2020-04-01 23:46:38,088 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# 2020-04-01 23:46:38,090 INFO sqlalchemy.engine.base.Engine ()
# 2020-04-01 23:46:38,093 INFO sqlalchemy.engine.base.Engine SELECT CAST('test collated returns' AS CHAR CHARACTER SET utf8mb4) COLLATE utf8mb4_bin AS anon_1
# 2020-04-01 23:46:38,094 INFO sqlalchemy.engine.base.Engine ()

# %% [markdown]
# ## Part 2a) ETL on the "YouTube Categories" JSON dataset:
# ### Extraction, transformation, load, and read using 2 methods from MySQL Database

# %%
# YouTube data has two parts: 1) Categories information in JSON format
                            # 2) Top Trending US YouTube Videos in a CSV file

# Part 1) YouTube Categories are seperated in a json file
yt_json_file = './resources/youtube_US_category_id.json'
yt_rawjson_df = pd.read_json(yt_json_file)

# %%
# Extract the category id and category titles, and set them into a list

# for i in yt_rawjson_df['items']:
#     #print(i['id'])
#     print(i['id'] + ' | ' + i['snippet']['title'])
    

category_id = [int(i['id']) for i in yt_rawjson_df['items']]
category_title = [str(i['snippet']['title']) for i in yt_rawjson_df['items']]

# Create a dataframe of the category id and title for later use
category_id_title_df = pd.DataFrame({'category_id': category_id, 'category_title': category_title})
category_id_title_df.head()
category_id_title_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 2 columns):
# category_id       32 non-null int64
# category_title    32 non-null object
# dtypes: int64(1), object(1)
# memory usage: 592.0+ bytes

# %%
# Drop Dulplicates and Sort by category_title
category_id_title_df.drop_duplicates(['category_id', 'category_title']).sort_values(by=['category_title'], ascending=False).head()
# Out:
#     category_id   category_title
# 8            21    Videoblogging
# 6            19  Travel & Events
# 31           44         Trailers
# 28           41         Thriller
# 4            17           Sports

# %%
# Load category_id_title_df to MySQL with Pandas
category_id_title_df.to_sql('yt_categories', con=engine, if_exists='append')
# Out:
# 2020-04-01 23:46:42,027 INFO sqlalchemy.engine.base.Engine DESCRIBE `yt_categories`
# 2020-04-01 23:46:42,034 INFO sqlalchemy.engine.base.Engine ()
# 2020-04-01 23:46:42,044 INFO sqlalchemy.engine.base.Engine ROLLBACK
# 2020-04-01 23:46:42,054 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE yt_categories (
# 	`index` BIGINT,
# 	category_id BIGINT,
# 	category_title TEXT
# )
#
#
# 2020-04-01 23:46:42,061 INFO sqlalchemy.engine.base.Engine ()
# 2020-04-01 23:46:42,106 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-04-01 23:46:42,111 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_yt_categories_index ON yt_categories (`index`)
# 2020-04-01 23:46:42,114 INFO sqlalchemy.engine.base.Engine ()
# 2020-04-01 23:46:42,155 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-04-01 23:46:42,164 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-04-01 23:46:42,172 INFO sqlalchemy.engine.base.Engine INSERT INTO yt_categories (`index`, category_id, category_title) VALUES (%s, %s, %s)
# 2020-04-01 23:46:42,175 INFO sqlalchemy.engine.base.Engine ((0, 1, 'Film & Animation'), (1, 2, 'Autos & Vehicles'), (2, 10, 'Music'), (3, 15, 'Pets & Animals'), (4, 17, 'Sports'), (5, 18, 'Short Movies'), (6, 19, 'Travel & Events'), (7, 20, 'Gaming')  ... displaying 10 of 32 total bound parameter sets ...  (30, 43, 'Shows'), (31, 44, 'Trailers'))
# 2020-04-01 23:46:42,187 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# Two ways in this notebook to pull the data directly from MySQL database
# Method 1) Use SQL Alchemy Engine - Result: successfully reads from MySQL Database:
engine.execute("SELECT * FROM yt_categories").fetchall()
# Out:
# 2020-04-01 23:46:42,635 INFO sqlalchemy.engine.base.Engine SELECT * FROM yt_categories
# 2020-04-01 23:46:42,639 INFO sqlalchemy.engine.base.Engine ()
# [(0, 1, 'Film & Animation'),
#  (1, 2, 'Autos & Vehicles'),
#  (2, 10, 'Music'),
#  (3, 15, 'Pets & Animals'),
#  (4, 17, 'Sports'),
#  (5, 18, 'Short Movies'),
#  (6, 19, 'Travel & Events'),
#  (7, 20, 'Gaming'),
#  (8, 21, 'Videoblogging'),
#  (9, 22, 'People & Blogs'),
#  (10, 23, 'Comedy'),
#  (11, 24, 'Entertainment'),
#  (12, 25, 'News & Politics'),
#  (13, 26, 'Howto & Style'),
#  (14, 27, 'Education'),
#  (15, 28, 'Science & Technology'),
#  (16, 29, 'Nonprofits & Activism'),
#  (17, 30, 'Movies'),
#  (18, 31, 'Anime/Animation'),
#  (19, 32, 'Action/Adventure'),
#  (20, 33, 'Classics'),
#  (21, 34, 'Comedy'),
#  (22, 35, 'Documentary'),
#  (23, 36, 'Drama'),
#  (24, 37, 'Family'),
#  (25, 38, 'Foreign'),
#  (26, 39, 'Horror'),
#  (27, 40, 'Sci-Fi/Fantasy'),
#  (28, 41, 'Thriller'),
#  (29, 42, 'Shorts'),
#  (30, 43, 'Shows'),
#  (31, 44, 'Trailers')]

# %%
# Method 2) Read from MySQL database using Pandas - Result: Success! - This method is a better setup for analysis.
# The index column is automatically generated.
pd.read_sql_query('SELECT * FROM yt_categories', con=engine).head()
# Out:
# 2020-04-01 23:46:43,450 INFO sqlalchemy.engine.base.Engine SELECT * FROM yt_categories
# 2020-04-01 23:46:43,454 INFO sqlalchemy.engine.base.Engine ()
#    index  category_id    category_title
# 0      0            1  Film & Animation
# 1      1            2  Autos & Vehicles
# 2      2           10             Music
# 3      3           15    Pets & Animals
# 4      4           17            Sports

# %% [markdown]
# ## Part 2b) ETL on the "YouTube Top Trending US Videos" dataset:
# ### Extraction, transformation, load, and read using 2 methods from MySQL Database

# %%
# Part 1) is the YouTube Top US Videos in a CSV
csv_file_yt = "./resources/youtube_USvideos.csv"
yt_rawdata_df = pd.read_csv(csv_file_yt, encoding='utf-8')

# %%
# view rows, count and datatypes
yt_rawdata_df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# 5      gHZ1Qz0KiKM      17.14.11
# 6      39idVpFF7NQ      17.14.11
# 7      nc99ccSXST0      17.14.11
# 8      jr9QtXwC9vc      17.14.11
# 9      TUmyygCMMGA      17.14.11
# 10     9wRQljFNDW8      17.14.11
# 11     VifQlJit6A0      17.14.11
# 12     5E4ZBSInqUU      17.14.11
# 13     GgVmn66oK_A      17.14.11
# 14     TaTleo4cOs8      17.14.11
# 15     kgaO45SyaO4      17.14.11
# 16     ZAQs-ctOqXQ      17.14.11
# 17     YVfyYrEmzgM      17.14.11
# 18     eNSN6qet1kE      17.14.11
# 19     B5HORANmzHw      17.14.11
# 20     vU14JY3x81A      17.14.11
# 21     6VhU_T463sU      17.14.11
# 22     _-aDHxoblr4      17.14.11
# 23     JBZTZZAcFTw      17.14.11
# 24     lZ68j2J_GOM      17.14.11
# 25     dRpNZV18N_g      17.14.11
# 26     fcVjitaM3LY      17.14.11
# 27     qeWvgZLz9yU      17.14.11
# 28     iIxy3JN3-jc      17.14.11
# 29     n30k5CwLhS4      17.14.11
# ...            ...           ...
# 40919  vDyYMcjf500      18.14.06
# 40920  3Q2j5ApzSqs      18.14.06
# 40921  GfxNGjfSKRY      18.14.06
# 40922  amtC28yfYCM      18.14.06
# 40923  9NC2saE5MbQ      18.14.06
# 40924  XdNOI-q70q4      18.14.06
# 40925  QgOXIEhHU1Y      18.14.06
# 40926  SQsPvrev_bQ      18.14.06
# 40927  _1LdMWlNYS4      18.14.06
# 40928  AFbu21AGSho      18.14.06
# 40929  hHaUQh6Gx-Q      18.14.06
# 40930  wI89nVn6LHk      18.14.06
# 40931  oLDbO545aKQ      18.14.06
# 40932  tiF9SzzzX_o      18.14.06
# 40933  Gs26bZTRkdU      18.14.06
# 40934  Qcj15vHJTtk      18.14.06
# 40935  2in8XqiElwc      18.14.06
# 40936  Xr2rgT9uEnA      18.14.06
# 40937  v7H_Or9Nr5I      18.14.06
# 40938  n_W54baizX8      18.14.06
# 40939  pcJo0tIWybY      18.14.06
# 40940  _QWZvU7VCn8      18.14.06
# 40941  7UoP9ABJXGE      18.14.06
# 40942  ju_inUnrLc4      18.14.06
# 40943  1PhPYr_9zRY      18.14.06
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# 40922  The Tonight Show|"Jimmy Fallon"|"Mindy Kaling"...    588133    6583
# 40923  camels|"cactus"|"pets"|"livestock"|"animals"|"...   5985284   33243
# 40924  Matt Stonie|"Megatoad"|"Competitive Eating"|"F...   2025376   50919
# 40925  Welcome to the party|"Diplo"|"Lil Pump"|"Frenc...  40087764  835657
# 40926  tyler the creator|"435"|"nice toenails"|"golf ...   2252933  129865
# 40927  dinosaurs|"dinos"|"paleo"|"paleontology"|"scis...   1925345   46673
# 40928  nat geo wild|"national geographic"|"wild"|"wil...   1165339   20248
# 40929  Mustard|"Nick"|"Jonas"|"Anywhere"|"10"|"Summer...   2653229   48889
# 40930  ABC|"americanidol"|"idol"|"american idol"|"rya...   2003345   19895
# 40931  terrible magicians|"rudy"|"mancuso"|"juanpa"|"...   3825440  196635
# 40932  the voice season 14|"the voice finale performa...   1437051   19930
# 40933  SciShow|"science"|"Hank"|"Green"|"education"|"...    979732   29038
# 40934  SNL|"Saturday Night Live"|"SNL Season 43"|"SNL...   8607264   66559
# 40935  Nicki Minaj new music|"Nicki Minaj Queen"|"Nic...   4945185  189265
# 40936  miniminter|"mm7games"|"simon"|"random"|"lie de...   3229540  109945
# 40937   LucastheSpider|"Animation"|"3D Animation"|"Cute"   8300584  266267
# 40938  daddy yankee reggaeton|"daddy yankee youtube"|...  41803845  628861
# 40939  Garden (Say It Like Dat)|"R&B"|"SZA"|"Top Dawg...   6004782  210802
# 40940  Graham Norton|"Graham Norton Show Official"|"E...   5564576   46351
# 40941  wedding video|"heartfelt wedding video"|"emoti...   5534278   45128
# 40942  fifth hamony|"harmonizers"|"lauren"|"ally"|"no...  23502572  676467
# 40943  BuzzFeed|"BuzzFeedVideo"|"Puppy Interview"|"pu...   8259128  645888
# 40944  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 40945                                             [none]   1064798   60008
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#        dislikes  comment_count  \
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# 5           511           1434
# 6          2445           1970
# 7           778           3432
# 8           119            340
# 9          1363           2368
# 10           25            177
# 11          303           1279
# 12         1333           8371
# 13         1171           3981
# 14          246           2120
# 15           52           1230
# 16          638           1256
# 17           53            385
# 18           36           2211
# 19          191           1214
# 20           75           2800
# 21          138            208
# 22           89           1014
# 23          578            673
# 24           52            234
# 25          193           1392
# 26           41            437
# 27          224           1346
# 28           36             83
# 29          238            246
# ...         ...            ...
# 40919      1333           1257
# 40920     14427          26162
# 40921       543            936
# 40922       381            486
# 40923      4899          16703
# 40924      2127           8253
# 40925     25283          38305
# 40926      1550           6673
# 40927      1765           4973
# 40928       668           2261
# 40929       890           1181
# 40930      2831           3481
# 40931      4514          11203
# 40932      1794           1671
# 40933      1121           2584
# 40934     14179           8382
# 40935      9406          18683
# 40936      3062           6774
# 40937      4237          14617
# 40938     42833          39363
# 40939      4166          15169
# 40940      2295           2861
# 40941      1591            806
# 40942     15993          52432
# 40943      4052          62610
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg              False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
#
# 40937  https://i.ytimg.com/vi/v7H_Or9Nr5I/default.jpg              False
# 40938  https://i.ytimg.com/vi/n_W54baizX8/default.jpg              False
# 40939  https://i.ytimg.com/vi/pcJo0tIWybY/default.jpg              False
# 40940  https://i.ytimg.com/vi/_QWZvU7VCn8/default.jpg              False
# 40941  https://i.ytimg.com/vi/7UoP9ABJXGE/default.jpg              False
# 40942  https://i.ytimg.com/vi/ju_inUnrLc4/default.jpg              False
# 40943  https://i.ytimg.com/vi/1PhPYr_9zRY/default.jpg              False
# 40944  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# 5                 False                   False
# 6                 False                   False
# 7                 False                   False
# 8                 False                   False
# 9                 False                   False
# 10                False                   False
# 11                False                   False
# 12                False                   False
# 13                False                   False
# 14                False                   False
# 15                False                   False
# 16                False                   False
# 17                False                   False
# 18                False                   False
# 19                False                   False
# 20                False                   False
# 21                False                   False
# 22                False                   False
# 23                False                   False
# 24                False                   False
# 25                False                   False
# 26                False                   False
# 27                False                   False
# 28                False                   False
# 29                False                   False
# ...                 ...                     ...
# 40919             False                   False
# 40920             False                   False
# 40921             False                   False
# 40922             False                   False
# 40923             False                   False
# 40924             False                   False
# 40925             False                   False
# 40926             False                   False
# 40927             False                   False
# 40928             False                   False
# 40929             False                   False
# 40930             False                   False
# 40931             False                   False
# 40932             False                   False
# 40933             False                   False
# 40934             False                   False
# 40935             False                   False
# 40936             False                   False
# 40937             False                   False
# 40938             False                   False
# 40939             False                   False
# 40940             False                   False
# 40941             False                   False
# 40942             False                   False
# 40943             False                   False
# 40944             False                   False
# 40945             False                   False
# 40946             False                   False
# 40947             False                   False
# 40948             False                   False
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# 5      Using the iPhone for the past two weeks -- her...
# 6      Embattled Alabama Senate candidate Roy Moore (...
# 7      Ice Cream Pint Combination Lock - http://amzn....
# 8      Inspired by the imagination of P.T. Barnum, Th...
# 9      For now, at least, we have better things to wo...
# 10     New England Patriots returner Dion Lewis blast...
# 11     Shiva arrives just in time as King Ezekiel att...
# 12     WATCH SILENCE MUSIC VIDEO ▶ https://youtu.be/T...
# 13     The world at large is improving, but some coun...
# 14     Today we go shopping for new fish for some of ...
# 15                For more information . . . stay tuned.
# 16     Pacific Rim was so good, we can’t believe they...
# 17     Check out our Patreon page: https://www.patreo...
# 18     aaaannnd now to fly out of ground effect! The ...
# 19     Thanks to 23AndMe for supporting SciShow. Thes...
# 20     What if there was a way to control your dreams...
# 21     At this year's DesignerCon, we meet up with Ir...
# 22     I'm visiting the University of Iowa's National...
# 23     On this episode of Sweet Digs, we tour Social ...
# 24     Why is it so hard to figure out other people's...
# 25     Visit http://www.Bongiovibrand.com\nand get 20...
# 26     James Grime is back and talking prime numbers....
# 27     YouTubes new channel!: https://www.youtube.com...
# 28     LeBron James gave another all-time press confe...
# 29     The opening of Freaks and Geeks Episode 6, I'm...
# ...                                                  ...
# 40919  Thanks to Skillshare for sponsoring this video...
# 40920  Pre-order Christina Aguilera’s new album ‘Libe...
# 40921  James Bay covers Taylor Swift's Delicate in th...
# 40922  Mindy Kaling chats with Jimmy about his though...
# 40923  Dromedary camels tear through prickly pear cac...
# 40924  Download Fortnite!! https://pixly.go2cloud.org...
# 40925  Official Video | Diplo, French Montana & Lil P...
# 40926  a random song laying around from the flower bo...
# 40927  Check out our NEW POSTER: https://store.dftba....
# 40928  Watch this beetle go from larvae to giant. The...
# 40929  Anywhere Out Now! http://smarturl.it/AnywhereM...
# 40930  Maddie Poppe the crowd the American Idol 2018 ...
# 40931  WATCH MORE ▶ https://youtu.be/Q9_WGkd_svIWATCH...
# 40932  Brynn Cartelli sings Adele's Skyfall during th...
# 40933  You might think you know how to survive if you...
# 40934  Footage from Prince Harry's (Mikey Day) weddin...
# 40935  Chun-Li (Live on SNL / 2018)Song Available Her...
# 40936  Talia: https://www.youtube.com/user/nataliahad...
# 40937  Lucas is a tiny spider to some...giant arachni...
# 40938  Daddy Yankee - Hielo (Video Oficial)Spotify: h...
# 40939  SZA's CTRL available on:Apple Music - http://s...
# 40940  Check out all that Emilia Clarke merch... Subs...
# 40941  Stream + Download:https://wmna.sh/speechlessht...
# 40942  Fifth Harmony available at iTunes http://smart...
# 40943  BTS with the PPS, the puppies. These adorable ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945                                                NaN
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40949 rows x 16 columns]

# %%
# Rename Columns
yt_statistics_data_df = yt_rawdata_df.rename(columns={"video_id":"Video ID", "trending_date":"Trending Date",
                                                "title":"Title", "channel_title":"Channel Title",
                                                "category_id":"category_id", "publish_time":"Publish Time",
                                                "tags":"Tags", "views":"Views",
                                                "likes":"Likes", "dislikes":"Dislikes", 
                                                "comment_count":"Comment Count", "thumbnail_link":"Thumbnail Link",
                                                "comments_disabled":"Comments Disabled", "ratings_disabled":"Ratings Disabled",
                                                "video_error_or_removed":"Video Error Or Removed", "description":"Description"
                                               })
yt_statistics_data_df.head()
# Out:
#       Video ID Trending Date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                Title          Channel Title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              Publish Time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
#                                                 Tags    Views   Likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
#
#    Dislikes  Comment Count                                  Thumbnail Link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       666           2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
#
#    Comments Disabled  Ratings Disabled  Video Error Or Removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          Description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  One year after the presidential election, John...
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  Today we find out if Link is a Nickelback amat...
# 4  I know it's been a while since we did this sho...

# %%
# Drop Cells with Missing Information
yt_statistics_data_df = yt_statistics_data_df.dropna(how="any")

# %%
# Drop Dulplicates and Sort by Trending Date
yt_statistics_data_df.drop_duplicates(['Video ID', 'Trending Date', 'Title', 'Channel Title', 'category_id', 'Publish Time']).sort_values(by=['Trending Date'], ascending=False).head()
# Out:
#           Video ID Trending Date  \
# 38051  EqeIRzY7hIU      18.31.05
# 38103  MAjY8mCTXWk      18.31.05
# 38081  LzuDyq0-1LM      18.31.05
# 38082  6SuMbFuKDf8      18.31.05
# 38083  yDiXQl7grPQ      18.31.05
#
#                                                    Title       Channel Title  \
# 38051                  6 Cheese Gadgets put to the Test!  CrazyRussianHacker
# 38103  周杰倫 Jay Chou【不愛我就拉倒 If You Don't Love Me, It's...     杰威爾音樂 JVR Music
# 38081  Why it's not a British royal wedding without f...                 Vox
# 38082  Backstreet Boys - Don't Go Breaking My Heart (...  BackstreetBoysVEVO
# 38083  Do You Hear Yanny or Laurel? (SOLVED with SCIE...         AsapSCIENCE
#
#        category_id              Publish Time  \
# 38051           28  2018-05-20T18:58:15.000Z
# 38103           10  2018-05-14T15:59:47.000Z
# 38081           25  2018-05-18T11:00:03.000Z
# 38082           10  2018-05-17T04:00:01.000Z
# 38083           28  2018-05-16T18:16:26.000Z
#
#                                                     Tags     Views   Likes  \
# 38051  Cheese Gadgets|"Gadgets"|"Cheese"|"kitchen gad...   1519038   26770
# 38103  周杰倫|"Jay"|"Chou"|"周董"|"周杰伦"|"周傑倫"|"杰威尔"|"周周"|"...  17259071  132009
# 38081  pop culture|"royal wedding"|"fancy hats"|"prin...    484199    8246
# 38082  Backstreet Boys|"Don't Go Breaking My Heart"|"...  14717193  396826
# 38083  AsapSCIENCE|"audio illusion"|"yanny"|"laurel"|...  42667467  564046
#
#        Dislikes  Comment Count  \
# 38051      1557           2875
# 38103      9552          14789
# 38081       662            761
# 38082     16015          39035
# 38083     33508         180469
#
#                                        Thumbnail Link  Comments Disabled  \
# 38051  https://i.ytimg.com/vi/EqeIRzY7hIU/default.jpg              False
# 38103  https://i.ytimg.com/vi/MAjY8mCTXWk/default.jpg              False
# 38081  https://i.ytimg.com/vi/LzuDyq0-1LM/default.jpg              False
# 38082  https://i.ytimg.com/vi/6SuMbFuKDf8/default.jpg              False
# 38083  https://i.ytimg.com/vi/yDiXQl7grPQ/default.jpg              False
#
#        Ratings Disabled  Video Error Or Removed  \
# 38051             False                   False
# 38103             False                   False
# 38081             False                   False
# 38082             False                   False
# 38083             False                   False
#
#                                              Description
# 38051  $1000 Survival Kit in a Case - https://youtu.b...
# 38103  詞：周杰倫、宋健彰（彈頭）  曲：周杰倫MV導演：周杰倫憂鬱型男的走心旋律  用英式搖滾宣洩...
# 38081  Fantastical fascinators at royal weddings are ...
# 38082  Get the Backstreet Boys new single “Don’t Go B...
# 38083  Yanny vs. Laurel audio illusion solved! PHEW F...

# %%
# Drop Unwanted Columns

to_drop =['Publish Time', 'Tags', 'Thumbnail Link', 'Comments Disabled', 'Ratings Disabled', 'Video Error Or Removed', 'Description']

yt_statistics_data_df.drop(to_drop, inplace=True, axis=1)

# %%
# Replace the "." in Trending Date to "-"

yt_statistics_data_df['Trending Date'] = [x.replace(".","-") for x in yt_statistics_data_df['Trending Date']]
yt_statistics_data_df.head()
# Out:
#       Video ID Trending Date  \
# 0  2kyS6SvSYSE      17-14-11
# 1  1ZAPwfrtAFY      17-14-11
# 2  5qpjK5DgCt4      17-14-11
# 3  puqaWrEC7tY      17-14-11
# 4  d380meD0W0M      17-14-11
#
#                                                Title          Channel Title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id    Views   Likes  Dislikes  Comment Count
# 0           22   748374   57527      2966          15954
# 1           24  2418783   97185      6146          12703
# 2           23  3191434  146033      5339           8181
# 3           24   343168   10172       666           2146
# 4           24  2095731  132235      1989          17518

# %%
# Pulled up this dataframe verify exactly how "Music" was spelled for the following step:
category_id_title_df['category_title'].value_counts()
# Out:
# Comedy                   2
# Drama                    1
# Anime/Animation          1
# Sports                   1
# Horror                   1
# Short Movies             1
# Gaming                   1
# Sci-Fi/Fantasy           1
# Shows                    1
# Videoblogging            1
# Education                1
# Science & Technology     1
# Movies                   1
# Thriller                 1
# Howto & Style            1
# Entertainment            1
# Family                   1
# Film & Animation         1
# Action/Adventure         1
# Music                    1
# Pets & Animals           1
# Autos & Vehicles         1
# Shorts                   1
# Foreign                  1
# Documentary              1
# Trailers                 1
# Nonprofits & Activism    1
# Classics                 1
# People & Blogs           1
# News & Politics          1
# Travel & Events          1
# Name: category_title, dtype: int64

# %%
# Used Pandas Merge aka (Join in Relational DB) Inner joined the Both YouTube Tables to find what Category_id 10 means:

yt_merged_df = pd.merge(yt_statistics_data_df, category_id_title_df, how='inner', on='category_id',
         left_index=False, right_index=False, sort=False)

yt_musicdata_df = yt_merged_df[yt_merged_df['category_title']  == 'Music']

# %%
# Only going to clean and focus on YT videos that are in the "Music" category_title:

# Clean Channel Title Column to set up the MAIN LOOP

yt_musicdata_df['Channel Title'] = [x.replace("VEVO","") for x in yt_musicdata_df['Channel Title']]
yt_musicdata_df['Channel Title'] = [x.replace("vevo","") for x in yt_musicdata_df['Channel Title']]
yt_musicdata_df['Channel Title'] = [x.replace("Vevo","") for x in yt_musicdata_df['Channel Title']]
yt_musicdata_df['Channel Title'] = [x.replace("Official","") for x in yt_musicdata_df['Channel Title']]
yt_musicdata_df['Channel Title'] = [x.replace("official","") for x in yt_musicdata_df['Channel Title']]
yt_musicdata_df['Channel Title'] = [x.replace("OFFICIAL","") for x in yt_musicdata_df['Channel Title']]
yt_musicdata_df['Channel Title'] = [x.replace("You Tube Channel","") for x in yt_musicdata_df['Channel Title']]
yt_musicdata_df['Channel Title'] = [x.replace("Music","") for x in yt_musicdata_df['Channel Title']]
yt_musicdata_df['Channel Title'] = [x.replace("music","") for x in yt_musicdata_df['Channel Title']]
yt_musicdata_df['Channel Title'] = [x.replace(" - Topic","") for x in yt_musicdata_df['Channel Title']]

yt_musicdata_df['Channel Title'].replace("BackstreetBoys","Backstreet Boys")
yt_musicdata_df['Channel Title'].replace("CalumScott","Calum Scott")
yt_musicdata_df['Channel Title'].replace("TaylorSwift","Taylor Swift")
yt_musicdata_df['Channel Title'].replace("NickiMinajAt","Nicki Minaj")
yt_musicdata_df['Channel Title'].replace("FifthHarmony","FifthHarmony")
yt_musicdata_df['Channel Title'].replace("davematthewsband","Dave Matthews Band")
yt_musicdata_df['Channel Title'].replace("EnriqueIglesias","Enrique Iglesias")
yt_musicdata_df['Channel Title'].replace("ChildishGambino","Childish Gambino")
yt_musicdata_df['Channel Title'].replace("SamSmithWorld","Sam Smith")
yt_musicdata_df['Channel Title'].replace("MeghanTrainor","Meghan Trainor")
yt_musicdata_df['Channel Title'].replace("johnmayer","John Mayer")
yt_musicdata_df['Channel Title'].replace("weezer","Weezer")
yt_musicdata_df['Channel Title'].replace("AzealiaBanks","Azealia Banks")
yt_musicdata_df['Channel Title'].replace("Maroon5","Maroon 5")
yt_musicdata_df['Channel Title'].replace("Zayn","ZAYN")
yt_musicdata_df['Channel Title'].replace("ArianaGrande","Ariana Grande")
yt_musicdata_df['Channel Title'].replace("CAguilera","Christina Aguilera")
yt_musicdata_df['Channel Title'].replace("LadyGaga","Lady Gaga")
yt_musicdata_df['Channel Title'].replace("ToniBraxton","Toni Braxton")
yt_musicdata_df['Channel Title'].replace("JasonAldean","Jason Aldean")
yt_musicdata_df['Channel Title'].replace("PTXofficial","PTX")
yt_musicdata_df['Channel Title'].replace("KeithUrban","Keith Urban")
yt_musicdata_df['Channel Title'].replace("KaceyMusgraves","Kacey Musgraves")
yt_musicdata_df['Channel Title'].replace("ChrisStapleton","Chris Stapleton")
yt_musicdata_df['Channel Title'].replace("ThirtySecondsToMars","Thirty Seconds To Mars")

# Clean Special Characters to prevent latin-1 encoding errors. Went back up to the pd.read_csv
# and added "encoding="utf-8"

yt_musicdata_df['Title'] = [x.replace("é","e") for x in yt_musicdata_df['Title']]
yt_musicdata_df['Title'] = [x.replace("ú","u") for x in yt_musicdata_df['Title']]
yt_musicdata_df['Title'] = [x.replace("®","") for x in yt_musicdata_df['Title']]
# Out:
# C:\Users\JOHNE\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\JOHNE\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\JOHNE\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\JOHNE\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\JOHNE\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\JOHNE\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\JOHNE\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\JOHNE\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\Users\JOHNE\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\JOHNE\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\JOHNE\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\JOHNE\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\JOHNE\Anaconda3\lib\site-packages\ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
yt_musicdata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6437 entries, 25550 to 31986
# Data columns (total 10 columns):
# Video ID          6437 non-null object
# Trending Date     6437 non-null object
# Title             6437 non-null object
# Channel Title     6437 non-null object
# category_id       6437 non-null int64
# Views             6437 non-null int64
# Likes             6437 non-null int64
# Dislikes          6437 non-null int64
# Comment Count     6437 non-null int64
# category_title    6437 non-null object
# dtypes: int64(5), object(5)
# memory usage: 553.2+ KB

# %%
# Load category_id_title_df to MySQL with Pandas
yt_musicdata_df.to_sql('yt_statistics', con=engine, if_exists='append')
# Out:
# 2020-04-01 23:46:49,332 INFO sqlalchemy.engine.base.Engine DESCRIBE `yt_statistics`
# 2020-04-01 23:46:49,340 INFO sqlalchemy.engine.base.Engine ()
# 2020-04-01 23:46:49,354 INFO sqlalchemy.engine.base.Engine ROLLBACK
# 2020-04-01 23:46:49,373 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE yt_statistics (
# 	`index` BIGINT,
# 	`Video ID` TEXT,
# 	`Trending Date` TEXT,
# 	`Title` TEXT,
# 	`Channel Title` TEXT,
# 	category_id BIGINT,
# 	`Views` BIGINT,
# 	`Likes` BIGINT,
# 	`Dislikes` BIGINT,
# 	`Comment Count` BIGINT,
# 	category_title TEXT
# )
#
#
# 2020-04-01 23:46:49,376 INFO sqlalchemy.engine.base.Engine ()
# 2020-04-01 23:46:49,423 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-04-01 23:46:49,426 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_yt_statistics_index ON yt_statistics (`index`)
# 2020-04-01 23:46:49,429 INFO sqlalchemy.engine.base.Engine ()
# 2020-04-01 23:46:49,458 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-04-01 23:46:49,470 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-04-01 23:46:49,591 INFO sqlalchemy.engine.base.Engine INSERT INTO yt_statistics (`index`, `Video ID`, `Trending Date`, `Title`, `Channel Title`, category_id, `Views`, `Likes`, `Dislikes`, `Comment Count`, category_title) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# 2020-04-01 23:46:49,592 INFO sqlalchemy.engine.base.Engine ((25550, '5E4ZBSInqUU', '17-14-11', 'Marshmello - Blocks (Official Music Video)', 'marshmello', 10, 687582, 114188, 1333, 8371, 'Music'), (25551, 'n1WpP7iowLc', '17-14-11', 'Eminem - Walk On Water (Audio) ft. Beyonce', 'Eminem', 10, 17158531, 787419, 43420, 125882, 'Music'), (25552, 'e_7zHm7GsYc', '17-14-11', 'Hunter Hayes - You Should Be Loved (Part One Of Pictures)', 'Hunter Hayes', 10, 13917, 1318, 24, 76, 'Music'), (25553, 'zZ9FciUx6gs', '17-14-11', 'Nickelback - The Betrayal Act III [Official Video]', 'Nickelback', 10, 57169, 6927, 161, 565, 'Music'), (25554, 'PaJCFHXcWmM', '17-14-11', 'U2 - The Blackout', 'U2', 10, 60506, 5389, 106, 455, 'Music'), (25555, '0tO_l_Ed5Rs', '17-14-11', 'Matthew Santoro - FACTS (Official Music Video) f. Ellevan & Humble the Poet', 'MatthewSantoro', 10, 328330, 15186, 15448, 7484, 'Music'), (25556, '9t9u_yPEidY', '17-14-11', 'Jennifer Lopez - Amor, Amor, Amor (Official Video) ft. Wisin', 'JenniferLopez', 10, 9548677, 190083, 15015, 11473, 'Music'), (25557, 'ujyTQNNjjDU', '17-14-11', 'G-Eazy - The Plan (Official Video)', 'GEazy', 10, 2642930, 115795, 3055, 6410, 'Music')  ... displaying 10 of 6437 total bound parameter sets ...  (31985, '7UoP9ABJXGE', '18-14-06', 'Dan + Shay - Speechless (Wedding Video)', 'Dan And Shay', 10, 5534278, 45128, 1591, 806, 'Music'), (31986, 'ju_inUnrLc4', '18-14-06', "Fifth Harmony - Don't Say You Love Me", 'FifthHarmony', 10, 23502572, 676467, 15993, 52432, 'Music'))
# 2020-04-01 23:46:50,148 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# Two ways in this notebook to pull the data directly from MySQL database
# Method 1) Use SQL Alchemy Engine - Result: successfully reads from MySQL Database:
engine.execute("SELECT * FROM yt_statistics").fetchall()
# Out:
# 2020-04-01 23:46:50,163 INFO sqlalchemy.engine.base.Engine SELECT * FROM yt_statistics
# 2020-04-01 23:46:50,166 INFO sqlalchemy.engine.base.Engine ()
# [(25550, '5E4ZBSInqUU', '17-14-11', 'Marshmello - Blocks (Official Music Video)', 'marshmello', 10, 687582, 114188, 1333, 8371, 'Music'),
#  (25551, 'n1WpP7iowLc', '17-14-11', 'Eminem - Walk On Water (Audio) ft. Beyonce', 'Eminem', 10, 17158531, 787419, 43420, 125882, 'Music'),
#  (25552, 'e_7zHm7GsYc', '17-14-11', 'Hunter Hayes - You Should Be Loved (Part One Of Pictures)', 'Hunter Hayes', 10, 13917, 1318, 24, 76, 'Music'),
#  (25553, 'zZ9FciUx6gs', '17-14-11', 'Nickelback - The Betrayal Act III [Official Video]', 'Nickelback', 10, 57169, 6927, 161, 565, 'Music'),
#  (25554, 'PaJCFHXcWmM', '17-14-11', 'U2 - The Blackout', 'U2', 10, 60506, 5389, 106, 455, 'Music'),
#  (25555, '0tO_l_Ed5Rs', '17-14-11', 'Matthew Santoro - FACTS (Official Music Video) f. Ellevan & Humble the Poet', 'MatthewSantoro', 10, 328330, 15186, 15448, 7484, 'Music'),
#  (25556, '9t9u_yPEidY', '17-14-11', 'Jennifer Lopez - Amor, Amor, Amor (Official Video) ft. Wisin', 'JenniferLopez', 10, 9548677, 190083, 15015, 11473, 'Music'),
#  (26534, 'dx0jvrlV_EQ', '17-13-12', 'The Maccabeats - Candles on the Sill - Hanukkah', 'MaccabeatsVideos', 10, 77201, 1855, 49, 166, 'Music'),
#  (26535, 'LRrzLpfdY1g', '17-13-12', 'Mary, Did You Know? | Anthem Lights', 'Anthem Lights', 10, 71008, 5042, 31, 268, 'Music'),
#  (26536, 'XiIShINrftE', '17-13-12', 'Taylor Swift - ‘Look What You Made Me Do’ (Live At Capital’s Jingle Bell Ball 2017)', 'Capital FM', 10, 970362, 32623, 3310, 2527, 'Music'),
#  (26537, 'SeVYqisjAQk', '17-13-12', 'Sheryl Crow - The Dreaming Kind (Official Music Video)', 'Sherylcrow', 10, 41174, 600, 109, 130, 'Music'),
#  (26538, 'xp0m08eOD5U', '17-13-12', 'Moby - Like A Motherless Child (Official Video)', 'Moby', 10, 102558, 3535, 155, 262, 'Music'),
#  (26539, 'oFqHvacY9Kk', '17-13-12', 'björk - the gate deconstructed', 'Björk', 10, 26304, 3294, 19, 213, 'Music'),
#  (26540, 'eWdZk_88r8I', '17-13-12', 'John Legend And Zara Larsson Perform God Only Knows At Nobel Peace Prize Concert 2017', 'blvck King', 10, 25383, 314, 4, 21, 'Music'),
#  (26541, 'o8m2kXgCIMc', '17-13-12', 'Brett Young - O Holy Night', 'BrettYoung', 10, 81650, 3435, 102, 149, 'Music'),
#  (26542, '9v_rtaye2yY', '17-13-12', 'Migos, Nicki Minaj, Cardi B - MotorSport', 'Migos', 10, 16824026, 478516, 25019, 55263, 'Music'),
#  (26543, '56KYMMGudcU', '17-13-12', 'Eminem - Untouchable (Audio)', 'Eminem', 10, 7446601, 350550, 33832, 88672, 'Music'),
#  (26544, 'eYJCjVkOImU', '17-13-12', 'Sam Smith - Palace (On The Record: The Thrill Of It All Live)', 'SamSmithWorld', 10, 2120269, 76765, 756, 3264, 'Music'),
#  (26545, 'inZzcTXYowY', '17-13-12', 'Louis Tomlinson - Miss You (Official Video)', 'LouisTomlinson', 10, 3306301, 390127, 2235, 33267, 'Music'),
#  (26546, 'HKIIgYFhQlE', '17-13-12', 'G-Eazy - Sober (Audio) ft. Charlie Puth', 'GEazy', 10, 2163869, 110914, 794, 4009, 'Music'),
#  (26547, 'fd7M_5xW0SI', '17-13-12', 'Sia - Ho Ho Ho', 'Sia', 10, 1643227, 85142, 1627, 4277, 'Music'),
#  (26548, 'sZWmwHjFRPI', '17-13-12', 'Charli XCX - Out Of My Head ft. Tove Lo and ALMA [Official Audio]', 'charlixcx', 10, 263108, 16444, 220, 953, 'Music'),
#  (26549, 'Nl6YEW1s7x8', '17-13-12', 'Mariah Carey - Lil Snowman', 'MariahCarey', 10, 501222, 12444, 1467, 1273, 'Music'),
#  ...]

# %%
# Method 2) Read from MySQL database using Pandas - Result: Success! - This method is a better setup for analysis.
# The index column is automatically generated.
pd.read_sql_query('SELECT * FROM yt_statistics', con=engine).head()
# Out:
# 2020-04-01 23:46:50,281 INFO sqlalchemy.engine.base.Engine SELECT * FROM yt_statistics
# 2020-04-01 23:46:50,282 INFO sqlalchemy.engine.base.Engine ()
#    index     Video ID Trending Date  \
# 0  25550  5E4ZBSInqUU      17-14-11
# 1  25551  n1WpP7iowLc      17-14-11
# 2  25552  e_7zHm7GsYc      17-14-11
# 3  25553  zZ9FciUx6gs      17-14-11
# 4  25554  PaJCFHXcWmM      17-14-11
#
#                                                Title Channel Title  \
# 0         Marshmello - Blocks (Official Music Video)    marshmello
# 1         Eminem - Walk On Water (Audio) ft. Beyonce        Eminem
# 2  Hunter Hayes - You Should Be Loved (Part One O...  Hunter Hayes
# 3  Nickelback - The Betrayal Act III [Official Vi...    Nickelback
# 4                                  U2 - The Blackout            U2
#
#    category_id     Views   Likes  Dislikes  Comment Count category_title
# 0           10    687582  114188      1333           8371          Music
# 1           10  17158531  787419     43420         125882          Music
# 2           10     13917    1318        24             76          Music
# 3           10     57169    6927       161            565          Music
# 4           10     60506    5389       106            455          Music

# %% [markdown]
# ## Part 2c) ETL on the "Spotify Top 2018 Songs" dataset:
# ### Extraction, transformation, load, and read using 2 methods from MySQL Database

# %%
# Spotify 2018 - Top 100 Songs - Raw CSV

csv_file_spotify2018 = "./resources/spotify_top2018.csv"
spotify2018_rawdata_df = pd.read_csv(csv_file_spotify2018)
spotify2018_rawdata_df.head()
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0          0.000083     0.552    0.357   77.169     198973.0             4.0
# 1          0.003720     0.123    0.473   75.023     166606.0             4.0
# 2          0.000066     0.131    0.140  159.847     218147.0             4.0
# 3          0.000000     0.112    0.439  140.124     221440.0             4.0
# 4          0.000060     0.396    0.350   91.030     217925.0             4.0

# %%
spotify2018_rawdata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
# id                  100 non-null object
# name                100 non-null object
# artists             100 non-null object
# danceability        100 non-null float64
# energy              100 non-null float64
# key                 100 non-null float64
# loudness            100 non-null float64
# mode                100 non-null float64
# speechiness         100 non-null float64
# acousticness        100 non-null float64
# instrumentalness    100 non-null float64
# liveness            100 non-null float64
# valence             100 non-null float64
# tempo               100 non-null float64
# duration_ms         100 non-null float64
# time_signature      100 non-null float64
# dtypes: float64(13), object(3)
# memory usage: 12.6+ KB

# %%
# Set up Spotify DataFrame
spotify_2018_id = spotify2018_rawdata_df['id']
spotify_2018_name = spotify2018_rawdata_df['name']
spotify_2018_artists = spotify2018_rawdata_df['artists']

# %%
spotify2018_filtered_df = pd.DataFrame({
            "Artist": spotify_2018_artists,
            "Song Name": spotify_2018_name,
            "Spotify Unique ID": spotify_2018_id
             })
spotify2018_filtered_df.head()
# Out:
#          Artist                     Song Name      Spotify Unique ID
# 0         Drake                    God's Plan  6DCZcSspjsKoFjzjrWoCd
# 1  XXXTENTACION                          SAD!  3ee8Jmje8o58CHK66QrVC
# 2   Post Malone    rockstar (feat. 21 Savage)  0e7ipj03S05BNilyu5bRz
# 3   Post Malone  Psycho (feat. Ty Dolla $ign)  3swc6WTsr7rl9DqQKQA55
# 4         Drake                In My Feelings  2G7V7zsVDxg1yRsu7Ew9R

# %%
# Load category_id_title_df to MySQL with Pandas
spotify2018_filtered_df.to_sql('spotify_2018top100_data', con=engine, if_exists='append')
# Out:
# 2020-04-01 23:46:52,813 INFO sqlalchemy.engine.base.Engine DESCRIBE `spotify_2018top100_data`
# 2020-04-01 23:46:52,819 INFO sqlalchemy.engine.base.Engine ()
# 2020-04-01 23:46:52,829 INFO sqlalchemy.engine.base.Engine ROLLBACK
# 2020-04-01 23:46:52,844 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE spotify_2018top100_data (
# 	`index` BIGINT,
# 	`Artist` TEXT,
# 	`Song Name` TEXT,
# 	`Spotify Unique ID` TEXT
# )
#
#
# 2020-04-01 23:46:52,849 INFO sqlalchemy.engine.base.Engine ()
# 2020-04-01 23:46:52,902 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-04-01 23:46:52,908 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_spotify_2018top100_data_index ON spotify_2018top100_data (`index`)
# 2020-04-01 23:46:52,913 INFO sqlalchemy.engine.base.Engine ()
# 2020-04-01 23:46:52,944 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-04-01 23:46:52,949 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-04-01 23:46:52,952 INFO sqlalchemy.engine.base.Engine INSERT INTO spotify_2018top100_data (`index`, `Artist`, `Song Name`, `Spotify Unique ID`) VALUES (%s, %s, %s, %s)
# 2020-04-01 23:46:52,954 INFO sqlalchemy.engine.base.Engine ((0, 'Drake', "God's Plan", '6DCZcSspjsKoFjzjrWoCd'), (1, 'XXXTENTACION', 'SAD!', '3ee8Jmje8o58CHK66QrVC'), (2, 'Post Malone', 'rockstar (feat. 21 Savage)', '0e7ipj03S05BNilyu5bRz'), (3, 'Post Malone', 'Psycho (feat. Ty Dolla $ign)', '3swc6WTsr7rl9DqQKQA55'), (4, 'Drake', 'In My Feelings', '2G7V7zsVDxg1yRsu7Ew9R'), (5, 'Post Malone', 'Better Now', '7dt6x5M1jzdTEt8oCbisT'), (6, 'Cardi B', 'I Like It', '58q2HKrzhC3ozto2nDdN4'), (7, 'Calvin Harris', 'One Kiss (with Dua Lipa)', '7ef4DlsgrMEH11cDZd32M')  ... displaying 10 of 100 total bound parameter sets ...  (98, 'ZAYN', 'Dusk Till Dawn - Radio Edit', '1j4kHkkpqZRBwE0A4CN4Y'), (99, 'Dean Lewis', 'Be Alright', '3EPXxR3ImUwfayaurPi3c'))
# 2020-04-01 23:46:52,962 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# Two ways in this notebook to pull the data directly from MySQL database
# Method 1) Use SQL Alchemy Engine - Result: successfully reads from MySQL Database:
engine.execute("SELECT * FROM spotify_2018top100_data").fetchall()
# Out:
# 2020-04-01 23:46:53,324 INFO sqlalchemy.engine.base.Engine SELECT * FROM spotify_2018top100_data
# 2020-04-01 23:46:53,331 INFO sqlalchemy.engine.base.Engine ()
# [(0, 'Drake', "God's Plan", '6DCZcSspjsKoFjzjrWoCd'),
#  (1, 'XXXTENTACION', 'SAD!', '3ee8Jmje8o58CHK66QrVC'),
#  (2, 'Post Malone', 'rockstar (feat. 21 Savage)', '0e7ipj03S05BNilyu5bRz'),
#  (3, 'Post Malone', 'Psycho (feat. Ty Dolla $ign)', '3swc6WTsr7rl9DqQKQA55'),
#  (4, 'Drake', 'In My Feelings', '2G7V7zsVDxg1yRsu7Ew9R'),
#  (5, 'Post Malone', 'Better Now', '7dt6x5M1jzdTEt8oCbisT'),
#  (6, 'Cardi B', 'I Like It', '58q2HKrzhC3ozto2nDdN4'),
#  (7, 'Calvin Harris', 'One Kiss (with Dua Lipa)', '7ef4DlsgrMEH11cDZd32M'),
#  (8, 'Dua Lipa', 'IDGAF', '76cy1WJvNGJTj78UqeA5z'),
#  (9, 'Marshmello', 'FRIENDS', '08bNPGLD8AhKpnnERrAc6'),
#  (10, 'Camila Cabello', 'Havana', '1rfofaqEpACxVEHIZBJe6'),
#  (11, 'Juice WRLD', 'Lucid Dreams', '0s3nnoMeVWz3989MkNQiR'),
#  (12, 'Drake', 'Nice For What', '3CA9pLiwRIGtUBiMjbZmR'),
#  (13, 'Maroon 5', 'Girls Like You (feat. Cardi B)', '7fa9MBXhVfQ8P8Df9OEbD'),
#  (14, 'Zedd', 'The Middle', '09IStsImFySgyp0pIQdqA'),
#  (15, 'Kendrick Lamar', 'All The Stars (with SZA)', '3GCdLUSnKSMJhs4Tj6CV3'),
#  (16, 'Ariana Grande', 'no tears left to cry', '2qT1uLXPVPzGgFOx4jtEu'),
#  (17, 'Nicky Jam', 'X', '39N9RPD9MRb5WmoLzNzPe'),
#  (18, 'XXXTENTACION', 'Moonlight', '0JP9xo3adEtGSdUEISisz'),
#  (19, 'BlocBoy JB', 'Look Alive (feat. Drake)', '4qKcDkK6siZ7Jp1Jb4m0a'),
#  (20, 'Rudimental', 'These Days (feat. Jess Glynne, Macklemore & Dan Caplen)', '5CLGzJsGqhCEECcpnFQA8'),
#  (21, 'Nio Garcia', 'Te Bot? - Remix', '3V8UKqhEK5zBkBb6d6ub8'),
#  (22, 'Bazzi', 'Mine', '7uzmGiiJyRfuViKKK3lVm'),
#  (23, '5 Seconds of Summer', 'Youngblood', '2iUXsYOEPhVqEBwsqP70r'),
#  (24, 'Dua Lipa', 'New Rules', '2xJCMIJfcNYDc5iR0sAm2'),
#  (25, 'Ed Sheeran', 'Shape of You', '7qiZfU4dY1lWllzX7mPBI'),
#  (26, 'Khalid', 'Love Lies (with Normani)', '45Egmo7icyopuzJN0oMEd'),
#  (27, 'Bebe Rexha', 'Meant to Be (feat. Florida Georgia Line)', '4e4fqjx0Izh4svvTef1z7'),
#  (28, 'XXXTENTACION', 'Jocelyn Flores', '7m9OqQk4RVRkw9JJdeAw9'),
#  (29, 'Ed Sheeran', 'Perfect', '0tgVpDi06FyKpA1z0VMD4'),
#  (30, 'Tyga', 'Taste (feat. Offset)', '5IaHrVsrferBYDm0bDyAB'),
#  (31, 'Clean Bandit', 'Solo (feat. Demi Lovato)', '6kPJZM97LwdG9QIsT7khp'),
#  (32, 'Post Malone', 'I Fall Apart', '75ZvA4QfFiZvzhj2xkaWA'),
#  (33, 'Dennis Lloyd', 'Nevermind', '63SevszngYpZOwf63o61K'),
#  (34, 'Luis Fonsi', '?chame La Culpa', '2hl6q70unbviGo3g1R7uF'),
#  (35, 'benny blanco', 'Eastside (with Halsey & Khalid)', '0d2iYfpKoM0QCKvcLCkBa'),
#  (36, 'Camila Cabello', 'Never Be the Same', '4eWQlBRaTjPPUlzacqEeo'),
#  (37, 'Selena Gomez', 'Wolves', '0tBbt8CrmxbjRP0pueQky'),
#  (38, 'XXXTENTACION', 'changes', '7AFASza1mXqntmGtbxXpr'),
#  (39, 'Dynoro', 'In My Mind', '0E9ZjEAyAwOXZ7wJC0PD3'),
#  (40, 'Eminem', 'River (feat. Ed Sheeran)', '1cS0TgbR263ey9jn0MwD2'),
#  (41, 'Daddy Yankee', 'Dura', '6KuqAtoeVzxAYOaMveLNp'),
#  (42, 'Travis Scott', 'SICKO MODE', '2xLMifQCjDGFmkHkpNLD9'),
#  (43, 'Imagine Dragons', 'Thunder', '1zB4vmk8tFRmM9UULNzbL'),
#  (44, 'Reik', 'Me Niego', '6jA8JUuPCGYjFcgw0AoM5'),
#  (45, 'Ti?sto', 'Jackie Chan', '4kWO6O1BUXcZmaxitpVUw'),
#  (46, 'Bruno Mars', 'Finesse (Remix) [feat. Cardi B]', '3Vo4wInECJQuz9BIBMOu8'),
#  (47, 'Selena Gomez', 'Back To You - From 13 Reasons Why ? Season 2 Soundtrack', '4hQ6UGyWQIGJmHSo0J88J'),
#  (48, 'NF', 'Let You Down', '52okn5MNA47tk87PeZJLE'),
#  (49, 'The Weeknd', 'Call Out My Name', '1gm616Plq4ScqNi7TVkZ5'),
#  (50, 'Offset', 'Ric Flair Drip (& Metro Boomin)', '7sO5G9EABYOXQKNPNiE9N'),
#  (51, 'Marshmello', 'Happier', '2dpaYNEQHiRxtZbfNsse9'),
#  (52, 'Sam Smith', 'Too Good At Goodbyes', '1mXVgsBdtIVeCLJnSnmtd'),
#  (53, 'Lil Dicky', 'Freaky Friday (feat. Chris Brown)', '10Igtw8bSDyyFs7KIsKng'),
#  (54, 'Imagine Dragons', 'Believer', '0pqnGHJpmpxLKifKRmU6W'),
#  (55, '6ix9ine', 'FEFE (feat. Nicki Minaj & Murda Beatz)', '2E124GmJRnBJuXbTb4cPU'),
#  (56, 'Jonas Blue', 'Rise', '3KLygy1YWhmrQx0GRs7IO'),
#  (57, 'Loud Luxury', 'Body (feat. brando)', '7K7MUBCnzgBAvMVW2RTWN'),
#  (58, 'Lil Uzi Vert', 'XO TOUR Llif3', '7GX5flRQZVHRAGd6B4TmD'),
#  (59, 'Becky G', 'Sin Pijama', '2ijef6ni2amuunRoKTlgw'),
#  (60, 'Anne-Marie', '2002', '2BgEsaKNfHUdlh97KmvFy'),
#  (90, 'Calvin Harris', 'Promises (with Sam Smith)', '5N5k9nd479b1xpDZ4usjr'),
#  (91, 'Lil Baby', 'Yes Indeed', '6vN77lE9LK6HP2DewaN6H'),
#  (92, 'Lauv', 'I Like Me Better', '2P91MQbaiQOfbiz9VqhqK'),
#  (93, 'Keala Settle', 'This Is Me', '2xGjteMU3E1tkEPVFBO08'),
#  (94, 'XXXTENTACION', 'Everybody Dies In Their Nightmares', '3GVkPk8mqxz0itaAriG1L'),
#  (95, 'Zac Efron', 'Rewrite The Stars', '630sXRhIcfwr2e4RdNtjK'),
#  (96, 'Clean Bandit', 'I Miss You (feat. Julia Michaels)', '2xmrfQpmS2iJExTlklLoA'),
#  (97, 'DJ Khaled', 'No Brainer', '5WvAo7DNuPRmk4APhdPzi'),
#  (98, 'ZAYN', 'Dusk Till Dawn - Radio Edit', '1j4kHkkpqZRBwE0A4CN4Y'),
#  (99, 'Dean Lewis', 'Be Alright', '3EPXxR3ImUwfayaurPi3c')]

# %%
# Method 2) Read from MySQL database using Pandas - Result: Success! - This method is a better setup for analysis.
# The index column is automatically generated.
pd.read_sql_query('SELECT * FROM spotify_2018top100_data', con=engine).head()
# Out:
# 2020-04-01 23:46:55,039 INFO sqlalchemy.engine.base.Engine SELECT * FROM spotify_2018top100_data
# 2020-04-01 23:46:55,044 INFO sqlalchemy.engine.base.Engine ()
#    index        Artist                     Song Name      Spotify Unique ID
# 0      0         Drake                    God's Plan  6DCZcSspjsKoFjzjrWoCd
# 1      1  XXXTENTACION                          SAD!  3ee8Jmje8o58CHK66QrVC
# 2      2   Post Malone    rockstar (feat. 21 Savage)  0e7ipj03S05BNilyu5bRz
# 3      3   Post Malone  Psycho (feat. Ty Dolla $ign)  3swc6WTsr7rl9DqQKQA55
# 4      4         Drake                In My Feelings  2G7V7zsVDxg1yRsu7Ew9R

# %% [markdown]
# ## Part 3) Investigating how many of Spotify Top 100 Songs were also Top Trending Videos in

# %%
j = yt_statistics.join(yt_categories, yt_statistics.c.category_id == yt_categories.c.category_id)
stmt = select([yt_statistics]).select_from(j)
result = conn.execute(stmt)
result.fetchall()
# Out:
# 2020-04-01 23:47:15,021 INFO sqlalchemy.engine.base.Engine SELECT yt_statistics.id, yt_statistics.category_title, yt_statistics.trending_date, yt_statistics.video_title, yt_statistics.channel_title, yt_statistics.category_id, yt_statistics.views, yt_statistics.likes, yt_statistics.dislikes, yt_statistics.view_count
# FROM yt_statistics INNER JOIN yt_categories ON yt_statistics.category_id = yt_categories.category_id
# 2020-04-01 23:47:15,022 INFO sqlalchemy.engine.base.Engine ()
# 2020-04-01 23:47:15,032 INFO sqlalchemy.engine.base.Engine ROLLBACK
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#
# ~\Anaconda3\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#
# ~\Anaconda3\lib\site-packages\MySQLdb\cursors.py in _query(self, q)
#     311         self._result = None
# --> 312         db.query(q)
#     313         self._do_get_result(db)
#
# ~\Anaconda3\lib\site-packages\MySQLdb\connections.py in query(self, query)
#     223             query = bytes(query)
# --> 224         _mysql.connection.query(self, query)
#     225
#
# OperationalError: (1054, "Unknown column 'yt_statistics.id' in 'field list'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-35-dd6a5d83d243> in <module>
#       1 j = yt_statistics.join(yt_categories, yt_statistics.c.category_id == yt_categories.c.category_id)
#       2 stmt = select([yt_statistics]).select_from(j)
# ----> 3 result = conn.execute(stmt)
#       4 result.fetchall()
#       5
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     507
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#     511     def do_execute_no_params(self, cursor, statement, context=None):
#
# ~\Anaconda3\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     204
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#     208
#
# ~\Anaconda3\lib\site-packages\MySQLdb\cursors.py in _query(self, q)
#     310         db = self._get_db()
#     311         self._result = None
# --> 312         db.query(q)
#     313         self._do_get_result(db)
#     314         self._post_get_result()
#
# ~\Anaconda3\lib\site-packages\MySQLdb\connections.py in query(self, query)
#     222         if isinstance(query, bytearray):
#     223             query = bytes(query)
# --> 224         _mysql.connection.query(self, query)
#     225
#     226     def _bytes_literal(self, bs):
#
# OperationalError: (MySQLdb._exceptions.OperationalError) (1054, "Unknown column 'yt_statistics.id' in 'field list'") [SQL: 'SELECT yt_statistics.id, yt_statistics.category_title, yt_statistics.trending_date, yt_statistics.video_title, yt_statistics.channel_title, yt_statistics.category_id, yt_statistics.views, yt_statistics.likes, yt_statistics.dislikes, yt_statistics.view_count \nFROM yt_statistics INNER JOIN yt_categories ON yt_statistics.category_id = yt_categories.category_id'] (Background on this error at: http://sqlalche.me/e/e3q8)
